# %% [markdown]
# ## Introduction
#
# In this project, we are taking a look at what makes an ice cream flavor more enjoyable for people to eat. We found this ice cream rating dataset on Kaggle which rates ice cream flavor of four ice cream producers and wish to understand the underlying reasons which makes an ice cream flavor rating higher than other ones.  Throughout this analysis, we will take a look at different hypotheses related to the type of ingredients contained within one ice cream, toppings used as well as what would be the perfect mix of toppings and ingredients which, could potentially produce the best rated ice cream flavor maximizing the ratings.

# %% [markdown]
# ## Data Set Description
#
# The dataset we chose is from Kaggle and contains reviews of multiple ice cream flavors across 4 major brands. Reviews comprise star ratings as well as a descriptive text which collected from the brand websites.
#
# Link: [https://www.kaggle.com/tysonpo/ice-cream-dataset](https://www.kaggle.com/tysonpo/ice-cream-dataset)
#
# - **products.csv**: contains information about each flavor
#     - 242 observations
#     - Variables: Ice cream key, brand name, name, subhead, description, rating, rating counts, ingredients
# - **reviews.csv**: contains reviews for each flavor of ice cream
#     - 21,674 observations
#     - Variables: Date of the review, star rating, title, helpful review indicator, review text
#
# Additional dataset:
# - **dairy.txt**: contains dairy keywords
#     - Source: https://www.godairyfree.org/dairy-free-grocery-shopping-guide/dairy-ingredient-list-2
#
# The dataset had to be cleaned in order to facilitate the statistical analysis to be done. This includes extracting the ingredient list, tokenizing it, and creating indicator variables. Additionally, we need to restrict the number of ingredients to keep track of to the following: raspberries, peanuts, almonds, coffee, chocolate, strawberries and raspberries. More will be added to this list following analysis on ingredient prevalence across flavors and brands.

# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
import numpy as np
import os
import re

# %%
#read csv files

#Data from kaggle:
#https://www.kaggle.com/tysonpo/ice-cream-dataset

df = pd.read_csv("products.csv")
df_reviews = pd.read_csv("reviews.csv")

#dairy free keywords
#https://www.godairyfree.org/dairy-free-grocery-shopping-guide/dairy-ingredient-list-2
dairy = pd.read_csv("dairy.txt", header = None)

# %%
def get_ingredients_dict(split_regex, ingredient_series):
    
    """
    Split ingredients series by chr string specified by regex
    Parent- separate by commas, ignore parenthesis 
    Child- separate by commas
    Return dictionary with keys as ingredients, values as frequency
    
    """
    
    ingredient_dict = {}
    for i in range(len(ingredient_series)):
        ingredient_split = [x.lstrip() for x in re.split(split_regex, ingredient_series[i]) if x != ""]
        for element in ingredient_split:
            if element in ingredient_dict.keys():
                ingredient_dict[element] = ingredient_dict[element] + 1
            else:
                ingredient_dict[element] = 1
    return ingredient_dict

# %%
def split_ingredients(split_regex):
    
    """
    Split ingredients series by chr string specified by regex
    Parent- separate by commas, ignore parenthesis 
    Child- separate by commas
    Return dictionary with keys as flavor keys, values as split ingredients
    """
    
    ingredient_dict = {}
    
    for i in range(len(df)):
        ingredient_split = [x.lstrip() for x in re.split(split_regex, df.iloc[i]["ingredients"]) if x != ""]
        ingredient_dict[df.iloc[i]["key"]] = ingredient_split
        
    return ingredient_dict

# %%
def indicator_df(split_regex):
    
    """
    Append ingredients count to dataframe
    """
    
    ing_dict = get_ingredients_dict(split_regex, df["ingredients"])
    indicator_df = pd.DataFrame({"ingredients" : ing_dict.keys()})
    
    return indicator_df

# %%
def ingredient_indicator(ing_dict, ing_df, columns = True):
    
    """
    ing_dict: ingredients dictionary preprocessed by Regular Expressions syntax
    ing_df: Target dataframe containing the individual flavors
    Columns: Add ingredients to columns, FALSE returns ingredients as rows (flavors as columns). Columns is default
    Returns tokenized dataframe
    """
    
    indicator_dict = {}
    
    for key in ing_dict.keys():
        indicator_dict[key] = [item in ing_dict[key] for item in ing_df["ingredients"]]
    
    indicator_df = ing_df.join(pd.DataFrame(data = indicator_dict))
    
    if columns:
        indicator_df = indicator_df.set_index("ingredients").transpose().reset_index().rename(columns = {"index" : "key"})
    
    return indicator_df

# %%
def contains_ingredient(target_ing_list, split_regex):
    
    """
    target_ing_list: List of ingredients to tokenize (dairy-free, etc.)
    split_regex: Syntax to split ingredients (parent, child)
    Returns DataFrame with tokenized ingredients given the ingredients list
    
    """
    split_ingredients_list = split_ingredients(split_regex)
    ind_df = indicator_df(split_regex)
    df_token = ingredient_indicator(split_ingredients_list, ind_df)
    
    df_target_ing = df_token[target_ing_list]
    
    return df_target_ing

# %%
def test_indicator(test_dict, test_df):
    
    indicator_dict = {}
    for key in test_dict.keys():
        print(key)
        indicator_dict[key] = [item in test_dict[key] for item in test_df["ingredients"]]

# %%
child_ing_indicator_df = ingredient_indicator(child_ing, indicator_df(child_regex), columns = False)

# %%
[item in list(dairy[0]) for item in child_ing_indicator_df["ingredients"]]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
list(dairy[0])
# Out:
# ['Acidophilus Milk',
#  'Ammonium Caseinate',
#  'Butter',
#  'Butter Esters',
#  'Butter Fat',
#  'Butter Oil',
#  'Butter Solids',
#  'Buttermilk',
#  'Buttermilk Powder',
#  'Calcium Caseinate',
#  'Casein',
#  'Caseinate',
#  'Cheese',
#  'Condensed Milk',
#  'Cottage Cheese',
#  'Cream',
#  'Cream Cheese',
#  'Curds',
#  'Custard',
#  'Delactosed Whey',
#  'Demineralized Whey',
#  'Dry Milk Powder',
#  'Dry Milk Solids',
#  'Evaporated Milk',
#  'Ghee',
#  'Goat Cheese',
#  'Goat Milk',
#  'Half & Half',
#  'Heavy Cream',
#  'Hydrolyzed Casein',
#  'Hydrolyzed Milk Protein',
#  'Ice Cream',
#  'Iron Caseinate',
#  'Lactalbumin',
#  'Lactoferrin',
#  'Lactoglobulin',
#  'Lactose',
#  'Lactulose',
#  'Low-Fat Milk',
#  'Magnesium Caseinate',
#  'Malted Milk',
#  'Milk',
#  'Milk Chocolate',
#  'Milk Derivative',
#  'Milk Fat',
#  'Milk Powder',
#  'Milk Protein',
#  'Milk Protein Concentrate',
#  'Milk Solids',
#  'Milkfat',
#  'Natural Butter Flavor',
#  'Nonfat Dry Milk',
#  'Nonfat Milk',
#  'Nonfat Milk Solids',
#  'Nougat',
#  'Paneer',
#  'Potassium Caseinate',
#  'Pudding',
#  'Recaldent',
#  'Rennet Casein',
#  'Sheep Milk',
#  'Sheep Milk Cheese',
#  'Skim Milk',
#  'Sodium Caseinate',
#  'Sour Cream',
#  'Sour Milk Solids',
#  'Sweetened Condensed Milk',
#  'Sweet Whey',
#  'Whey',
#  'Whey Powder',
#  'Whey Protein Concentrate',
#  'Whey Protein Hydrolysate',
#  'Whipped Cream',
#  'Whipped Topping',
#  'Whole Milk',
#  'Whole Milk Powder',
#  'Yogurt',
#  'Zinc Caseinate']

# %%
parents_regex = r'[.,]\s*(?![^()]*\))'
child_regex = r'[.,:()]'

# %%
parents_ing = split_ingredients(parents_regex)
child_ing = split_ingredients(child_regex)

# %%
indicator_df = indicator_df(parents_regex)

# %%
tokenize_df = ingredient_indicator(parents_ing, indicator_df, columns = False)
tokenize_df
# Out:
#                      ingredients   0_bj   1_bj   2_bj   3_bj   4_bj   5_bj  \
# 0                          CREAM   True   True   True   True   True   True
# 1                      SKIM MILK   True   True   True   True   True   True
# 2    LIQUID SUGAR (SUGAR, WATER)   True   True   True   True   True   True
# 3                          WATER   True   True   True   True   True   True
# 4                    BROWN SUGAR   True  False  False  False  False   True
# ..                           ...    ...    ...    ...    ...    ...    ...
# 446                 CREAM (MILK)  False  False  False  False  False  False
# 447          THIAMIN MONONITRATE  False  False  False  False  False  False
# 448             SKIM MILK POWDER  False  False  False  False  False  False
# 449    SOY LECITHIN (EMULSIFIER)  False  False  False  False  False  False
# 450       PASTEURIZED WHOLE EGGS  False  False  False  False  False  False
#
#       6_bj   7_bj   8_bj  ...  59_breyers  60_breyers  61_breyers  62_breyers  \
# 0     True   True   True  ...        True        True        True        True
# 1     True   True   True  ...        True       False       False       False
# 2     True   True   True  ...       False       False       False       False
# 3     True   True   True  ...        True       False        True       False
# 4    False  False  False  ...       False       False       False        True
# ..     ...    ...    ...  ...         ...         ...         ...         ...
# 446  False  False  False  ...       False       False       False       False
# 447  False  False  False  ...       False       False       False       False
# 448  False  False  False  ...       False       False       False       False
# 449  False  False  False  ...       False       False       False       False
# 450  False  False  False  ...       False       False       False       False
#
#      63_breyers  64_breyers  65_breyers  66_breyers  67_breyers  68_breyers
# 0          True        True        True        True        True        True
# 1         False       False       False       False       False       False
# 2         False       False       False       False       False       False
# 3          True        True        True        True       False        True
# 4         False        True       False       False       False       False
# ..          ...         ...         ...         ...         ...         ...
# 446       False       False       False        True       False       False
# 447       False       False       False       False        True       False
# 448       False       False       False       False        True       False
# 449       False       False       False       False       False        True
# 450       False       False       False       False       False        True
#
# [451 rows x 242 columns]

# %% [markdown]
# Below are WIP

# %%
#Append dairy free keywords to df

is_dairy = []
for ing_parent in ingredients:
    if ing_parent.title() in dairy[0].to_list():
        is_dairy.append(ing_parent)
    ing_par_list = re.split(r'[.,:()]',ing_parent)
    for ing_child in ing_par_list:
        if ing_child.strip().title() in dairy[0].to_list():
            is_dairy.append(ing_parent)
dairy_list = list(set(is_dairy))

# %%
dairy_list
# Out:
# ['WEET CREAM ICE CREAM: CREAM',
#  'BUTTER (MILK)',
#  'CREAM (MILK)',
#  'MILK CHOCOLATE',
#  'CARAMEL ICE CREAM: CREAM',
#  'MILK FAT',
#  'BUTTER',
#  'CREAM CHEESE (CREAM, MILK, CHEESE CULTURE, SALT, GUAR GUM, CAROB BEAN GUM, XANTHAN GUM)',
#  'CREAM CHEESE',
#  'SWEETENED CONDENSED MILK (CONDENSED MILK SUGAR)',
#  'CONDENSED MILK',
#  'HEAVY CREAM',
#  'CONTAINS: MILK',
#  'WHITE CHOCOLATE ICE CREAM: CREAM',
#  'MILK',
#  'CREAM CHEESE (MILK, CREAM, CHEESE CULTURE, SALT, CAROB GUM, GUAR GUM, XANTHAN GUM)',
#  'ULCE DE LECHE ICE CREAM: CREAM',
#  'BUTTER (CREAM)',
#  'SWEETENED CONDENSED MILK',
#  'ORGANIC BUTTER (CREAM, SALT)',
#  'CHOCOLATE ICE CREAM: CREAM',
#  'WHEY PROTEIN CONCENTRATE',
#  'LACTOSE',
#  'CARAMEL SWIRL: SWEETENED CONDENSED MILK (MILK, SUGAR)',
#  'BUTTER (CREAM, SALT)',
#  'MILK CHOCOLATE AND VEGETABLE OIL COATING: MILK CHOCOLATE (SUGAR, WHOLE MILK POWDER, CHOCOLATE, COCOA BUTTER, SOY LECITHIN, VANILLA EXTRACT)',
#  'SWEETENED CONDENSED SKIM MILK (SKIM MILK, SUGAR)',
#  'CREAM CHEESE (PASTEURIZED MILK, CREAM, CHEESE CULTURES, SALT, CAROB BEAN GUM)',
#  'SKIM MILK',
#  'WHOLE MILK POWDER',
#  'WHEY',
#  'NONFAT MILK SOLIDS',
#  'SWEETENED CONDENSED MILK (MILK,SUGAR)',
#  'CREAM CHEESE (CULTURED PASTEURIZED MILK AND CREAM, SALT, ENZYMES)',
#  'BUTTER OIL',
#  'CREAM CHEESE (PASTEURIZED MILK AND CREAM, CHEESE CULTURE, SALT, CAROB BEAN GUM, GUAR GUM)',
#  'MILK PROTEIN CONCENTRATE',
#  'MILKFAT',
#  'CREAM',
#  'SODIUM CASEINATE',
#  'NONFAT DRY MILK',
#  'NONFAT MILK',
#  'VANILLA ICE CREAM: CREAM',
#  'WHITE CHOCOLATE ICE CREAM (CREAM, SKIM MILK, SUGAR, CORN SYRUP, EGG YOLKS, NATURAL FLAVOR, COCOA BUTTER)',
#  'EVAPORATED MILK']

# %%
#pd.DataFrame(data = ingredients).sort_values(by = 0).to_csv("testdf.csv")

# %%
nondairy = [x for x in ingredients if x not in dairy_list]
pd.DataFrame(data = nondairy).to_csv("nondairy.csv")

# %%
df.sort_values(by = "rating").tail()
# Out:
#     brand    key                                               name  \
# 101    hd  44_hd                      Peppermint Bark Ice Cream Bar
# 7      bj   7_bj                      Chocolate Peanut Butter Split
# 29     bj  29_bj                                   Ice Cream Sammie
# 71     hd  14_hd                      Chocolate Fudge Non-Dairy Bar
# 120    hd  63_hd  Vanilla Caramel White Chocolate TRIO CRISPY LA...
#
#                                                subhead  \
# 101                                                NaN
# 7    Chocolate & Banana Ice Creams with Mini Peanut...
# 29   Vanilla Ice Cream with Chocolate Sandwich Cook...
# 71                                                 NaN
# 120                                                NaN
#
#                                            description  rating  rating_count  \
# 101  Our peppermint bark ice cream bars start with ...     5.0             8
# 7    We’ve loaded our banana and chocolate ice crea...     5.0             7
# 29   To capture the great taste of the classic ice ...     5.0            31
# 71   Enjoy an indulgent non-dairy and vegan bar mad...     5.0            22
# 120  This incredible combination of tastes and text...     5.0            32
#
#                                            ingredients  ingredients_count
# 101  WHITE CHOCOLATE ICE CREAM: CREAM, SKIM MILK, S...                 11
# 7    CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...                 20
# 29   CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...                 22
# 71   WATER, SUGAR, CORN SYRUP, CHOCOLATE, COCONUT O...                 18
# 120  CREAM, SKIM MILK, SUGAR, SWEETENED CONDENSED M...                 38

# %%
nondairy
# Out:
# ['ARTIFICIAL FLAVORS',
#  'RAISINS',
#  'PINEAPPLE',
#  'CANE SUGAR',
#  'POTATO FLOUR',
#  'WHEAT BRAN',
#  'ALMONDS ROASTED IN VEGETABLE OIL',
#  'VEGETABLE JUICE (FOR COLOR), PEPPERMINT OIL, SOY LECITHIN)',
#  'RASPBERRY PUREE',
#  'PECANS',
#  'SODIUM ACID PYROPHOSPHATE',
#  'UNBLEACHED UNENRICHED WHEAT FLOUR',
#  'ORANGE JUICE CONCENTRATE',
#  'CHOCOLATY COATING: SUGAR',
#  'GRAHAM CRUMB',
#  'PUMPKIN PUREE',
#  'ORGANIC CARAMELIZED SUGAR (ORGANIC CANE SUGAR, WATER)',
#  'SORBITOL',
#  'BLUEBERRY PUREE CONCENTRATE',
#  'SEMI-SWEET CHOCOLATE CHUNKS',
#  'OREO COOKIE PIECES',
#  'CHERRY PUREE',
#  'CITRIC ACID (TO MAINTAIN FRESHNESS)',
#  'LEMON JUICE CONCENTRATE',
#  'PGPR (EMULSIFIER)',
#  'MAY CONTAIN OTHER TREE NUTS',
#  'TBHQ AND CITRIC ACID (TO MAINTAIN FRESHNESS)',
#  'COCOA PROCESSED WITH ALKALI',
#  'SOYBEAN LECITHIN',
#  'THIAMIN MONONITRATE',
#  'COCONUT AND SOYBEAN OIL',
#  'CHOCOLATE (PROCESSED WITH ALKALI)',
#  'VEGETABLE GUMS',
#  'YELLOW 6',
#  'CHOCOLATE COOKIE PIECES',
#  'WHOLE EGG',
#  'VEGETABLE GUM (GUAR)',
#  'LOCUST BEAN GUM',
#  "REESE'S PEANUT BUTTER SWIRL",
#  'CAROB BEAN',
#  'THIAMINE MONONITRATE',
#  'BROWN SUGAR†',
#  'ORGANIC CREAM',
#  'PISTACHIOS',
#  'FUDGE COATING',
#  'CARAMELIZED SUGAR SYRUP',
#  'CREAM OF TARTAR',
#  'ASCORBIC ACID',
#  'CAROB BEAN GUM',
#  'TBHQ (PRESERVATIVE)',
#  'SOY LECITHIN NATURAL FLAVOR',
#  'PLUM',
#  'PUMPKIN JUICE CONCENTRATE',
#  'LEMON PEEL',
#  'PEPPERMINT EXTRACT',
#  'FRUIT AND VEGETABLE JUICE (FOR COLOR)',
#  'ROASTED ALMONDS (ALMONDS, PEANUT OIL)',
#  'ORGANIC CANE SUGAR',
#  'DRIED APPLES',
#  'ACESULFAME POTASSIUM',
#  'LEMON OIL',
#  'BLACK RASPBERRY PUREE',
#  'MODIFIED CORNSTARCH',
#  'RASPBERRY SWIRL',
#  'DRIED CANE SYRUP',
#  'OATS',
#  'COFFEE EXTRACT CONCENTRATE',
#  'TARA GUM',
#  'WATER',
#  'PALM AND PALM KERNEL OIL',
#  'STRAWBERRIES',
#  'LACTOSE REDUCED SKIM MILK',
#  'ERYTHRITOL',
#  'MANGO PUREE',
#  'CORNSTARCH',
#  'BOURBON',
#  'CHEESE CULTURES',
#  'EGG YOLKS',
#  'ALMOND EXTRACT',
#  'POLYDEXTROSE',
#  'BLUE 2 LAKE',
#  'TARA',
#  'VEGETABLE JUICE CONCENTRATE COLOR',
#  'SODIUM CITRATE',
#  'ORGANIC BUTTER (ORGANIC CREAM, SALT)',
#  'XANTHAN GUM',
#  'NUTMEG',
#  'ENRICHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMIN MONONITRATE, RIBOFLAVIN, FOLIC ACID)',
#  'EXPELLER PRESSED SOYBEAN OIL',
#  'CHERRY JUICE CONCENTRATE',
#  'TAPIOCA FLOUR',
#  'CLOVES',
#  'CARRAGEENAN',
#  'FRUIT AND VEGETABLE CONCENTRATES (COLOR)',
#  'DARK CHOCOLATE (BELGIAN CHOCOLATE, SUGAR, COCOA BUTTER, SOY LECITHIN, VANILLA)',
#  'RED CABBAGE JUICE CONCENTRATE (FOR COLOR)',
#  'PEPPERMINT BARK PIECES (SUGAR',
#  'CHEESE CULTURE',
#  'PEANUT BUTTER (PEANUTS)',
#  'CARAMEL FLAVOR',
#  'WAFFLE CONE PIECES',
#  "CONFECTIONER'S GLAZE",
#  'INVERT SUGAR',
#  'COCOA BUTTER',
#  'FUDGE COVERED WAFFLE CONE PIECES',
#  'MODIFIED FOOD STARCH (TAPIOCA)',
#  'CONTAINS MILK',
#  'ORGANIC VANILLA EXTRACT',
#  'VEGETABLE JUICE (FOR COLOR)',
#  'WHISKEY',
#  'CHOCOLATE LIQUOR (PROCESSED WITH ALKALI)',
#  'UNBLEACHED ENRICHED WHEAT FLOUR',
#  'MILK CHOCOLATE AND VEGETABLE OIL COATING',
#  'DEXTROSE',
#  'CARAMEL SWIRL: BROWN SUGAR',
#  'LACTASE',
#  'BLEACHED WHEAT FLOUR',
#  'MALIC ACID',
#  'COCONUT AND SOYBEAN AND SUNFLOWER OILS',
#  'DUTCHED COCOA (PROCESSED WITH ALKALI)',
#  'SUCRALOSE',
#  'MINT LEAF EXTRACTIVES',
#  'COCONUT CREAM',
#  'POTASSIUM SORBATE (PRESERVATIVE)',
#  'CHOCOLATE COOKIE: BLEACHED WHEAT FLOUR',
#  'WHOLE EGGS',
#  'WHEAT FLOUR',
#  'ENRICHED WHEAT FLOUR',
#  'CHOCOLATE PROCESSED WITH ALKALI',
#  'ANHYDROUS MILKFAT',
#  'WINE',
#  'CARAMEL SWIRL',
#  'BLUEBERRIES',
#  'SUNFLOWER LECITHIN',
#  'APPLE JUICE',
#  'CINNAMON',
#  'ORGANIC DEXTROSE',
#  'BARLEY MALT',
#  'COTTONSEED OIL',
#  'PGPR',
#  'SUNFLOWER OIL',
#  'VANILLA EXTRACT',
#  'GINGER',
#  'ENRICHED WHEAT FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMIN MONONITRATE, RIBOFLAVIN, FOLIC ACID)',
#  'GREEN TEA',
#  'BEET JUICE (FOR COLOR)',
#  'PLUM CONCENTRATE (FOR COLOR)',
#  'REDUCED IRON',
#  'VANILLA ICE CREAM',
#  'ORGANIC MATCHA GREEN TEA',
#  'CORN MALTODEXTRIN',
#  'WHEAT AND SOY',
#  'COLOR ADDED',
#  'VEGETABLE GUM (TARA)',
#  'INGREDIENTS: ORGANIC SKIM MILK',
#  'EGG YOLK AND WHOLE EGG',
#  'ROASTED PISTACHIOS: PISTACHIOS',
#  'ALMONDS',
#  'RED 40 LAKE',
#  'TAPIOCA STARCH',
#  'MILK CHOCOLATE CANDIES',
#  'GUAR GUM',
#  'SPICES',
#  'THIAMIN MONONITRATE (VITAMIN B1)',
#  'CHOCOLATEY COATED PEANUTS',
#  'BLACK CHERRIES',
#  'BLACKBERRY JUICE CONCENTRATE',
#  'ENRICHED FLOUR',
#  'GLYCERIN',
#  'CORN STARCH',
#  'POWDERED SUGAR',
#  'BUTTEROIL',
#  'CORN OIL',
#  'ORGANIC EGG WHITES AND EGG YOLKS',
#  'ORGANIC LEMON JUICE CONCENTRATE',
#  'RASPBERRIES',
#  'MALTITOL SYRUP',
#  'SALTED CARAMEL SWIRL: CORN SYRUP',
#  'CHEESECAKE BASE',
#  'MONO AND DIGLYCERIDES',
#  'VERMOUTH',
#  'SPICE',
#  'COFFEE ICE CREAM',
#  'UNSWEETENED CHOCOLATE',
#  'EGG AND SOY INGREDIENTS',
#  'LEMON JUICE',
#  'BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE)',
#  'SOY LECITHIN (EMULSIFIER)',
#  'SALT',
#  'PUMPKIN',
#  'SOYBEAN OIL',
#  'WHOLE WHEAT GRAHAM FLOUR',
#  'SEA SALT',
#  'TAPIOCA SYRUP',
#  'CHOCOLATE',
#  'VANILLIN (ARTIFICIAL FLAVOR)',
#  'NATURAL FLAVORS (CONTAINS BARLEY)',
#  'PEANUT FLOUR',
#  'MANGOS',
#  'HIBISCUS FLOWER',
#  'CORN SYRUP†',
#  'HAZELNUTS',
#  'CHOCOLATE FLAVORED COATING',
#  'PEACHES',
#  'VANILLA',
#  'PEA PROTEIN',
#  'BLUE 1 LAKE',
#  'WHOLE WHEAT/GRAHAM FLOUR',
#  'AND/OR PALM OIL',
#  'WHITE CHOCOLATE ICE CREAM',
#  'PEANUT OIL',
#  'AND/OR CANOLA OIL',
#  "REESE'S PEANUT BUTTER SAUCE",
#  'STRAWBERRY PUREE',
#  'RICE FLOUR',
#  "REESE'S PEANUT BUTTER CUP PIECES",
#  'MALTODEXTRIN (CORN)',
#  'THIAMINE MONONITRATE (VITAMIN B1)',
#  'ROASTED ALMONDS',
#  'NATURAL FLAVOR (COCONUT)',
#  'ROLLED OATS',
#  'CALCIUM CARBONATE',
#  'TBHQ (TO MAINTAIN FRESHNESS)',
#  'YELLOW 5 LAKE',
#  'LIQUID SUGAR',
#  'COCOA (PROCESSED WITH ALKALI)',
#  'CONDENSED SKIM MILK',
#  'PALM OIL AND SOYBEAN OIL',
#  'CHERRY AND BLACK CARROT CONCENTRATES (FOR COLOR)',
#  'SALTED FUDGE SWIRL: POWDERED CANE SUGAR (CANE SUGAR, CORN STARCH)',
#  'BANANAS',
#  'WHOLE EGG AND EGG YOLK',
#  'SWEETENED LEMON ZEST',
#  'BLACK RASPBERRIES',
#  'SNICKERS PIECES*',
#  'ARTIFICIAL COLOR',
#  'ANNATTO (COLOR)',
#  'WALNUTS',
#  'ORGANIC COCOA PROCESSED WITH ALKALI',
#  'CHOCOLATY COATED CONE PIECES',
#  'ANNATTO (FOR COLOR)',
#  'ORANGE JUICE (FROM CONCENTRATE)',
#  'AND/OR BAKING SODA',
#  'SKIM MILK POWDER',
#  'RED 40',
#  'VITAMIN A PALMITATE',
#  'ORGANIC GLUCOSE SYRUP',
#  'BUTTERFAT',
#  "M&M'S MINIS MILK CHOCOLATE CANDIES WITH COCOA BUTTER",
#  'COCOA POWDER',
#  'FRUCTOSE',
#  'COFFEE',
#  'HEATH TOFFEE BAR PIECES',
#  'ORGANIC CHOCOLATE',
#  'CONE PIECES',
#  'ORGANIC SKIM MILK',
#  'CELLULOSE GUM',
#  'DEXTRIN',
#  'CHOCOLATEY CHIPS',
#  'CARAMEL COLOR',
#  'LACTASE ENZYME',
#  'BAKING POWDER',
#  'EGG YOLKS AND EGG WHITES',
#  'COCONUT CREAM (COCONUT EXTRACT, WATER)',
#  'PALM OIL AND/OR CANOLA OIL',
#  'YELLOW 6 LAKE',
#  'PEPPERMINT TWISTS CANDY (SUGAR',
#  'DARK CHOCOLATE DRIZZLE WITH VEGETABLE OIL: DARK CHOCOLATE (SUGAR, CHOCOLATE, SOY LECITHIN, VANILLA EXTRACT)',
#  'COCOA POWDER (PROCESSED WITH ALKALI)',
#  'RUM',
#  'PASTEURIZED EGGS',
#  'COCONUT EXTRACT',
#  'ORGANIC BLACK COCOA PROCESSED WITH ALKALI',
#  'REB A (STEVIA LEAF EXTRACT)',
#  'DARK CHOCOLATE AND VEGETABLE OIL COATING WITH PEPPERMINT CANDY PIECES: DARK CHOCOLATE (SUGAR, CHOCOLATE, SOY LECITHIN, VANILLA EXTRACT)',
#  'PEANUTS',
#  'PALM AND SOYBEAN OILS',
#  'LIQUID SUGAR (SUGAR, WATER)',
#  'BROWN SUGAR',
#  'OAKWOOD EXTRACT',
#  'STRAWBERRY SWIRL',
#  'CITRIC ACID',
#  'MODIFIED FOOD STARCH (CORN)',
#  'PROPYLENE GLYCOL MONOESTERS',
#  'BLUE 1',
#  'FOLIC ACID',
#  'DESICCATED COCONUT',
#  'EGG',
#  'LIME JUICE CONCENTRATE',
#  'PEANUT EXTRACT',
#  'VANILLA BEAN SEEDS',
#  'UNBLEACHED ENRICHED FLOUR',
#  'BLACK CARROT CONCENTRATE (FOR COLOR)',
#  'SUGAR',
#  'GRAPE JUICE CONCENTRATE',
#  'ORGANIC MILK',
#  'PECTIN',
#  'SOLUBLE CORN FIBER',
#  'MODIFIED CORN STARCH',
#  'PALM OIL',
#  'HONEY',
#  'RIBOFLAVIN (VITAMIN B2)',
#  'RIBOFLAVIN',
#  'MANGO',
#  'COCONUT OIL',
#  'VEGETABLE OIL (CANOLA, SAFFLOWER, AND/OR SUNFLOWER OIL)',
#  'YELLOW 5',
#  'BALSAMIC VINEGAR (RED WINE VINEGAR, GRAPE MUST)',
#  'VANILLA BEANS',
#  'RED CABBAGE JUICE (COLOR)',
#  'WHEAT GERM',
#  'GUAR',
#  'HYDROGENATED VEGETABLE OIL',
#  'MOLASSES†',
#  "REESE'S PEANUT BUTTER CUPS",
#  'CORN SYRUP SOLIDS',
#  'BANANA PUREE',
#  'LOCUST BEAN',
#  "REESE'S MINI PIECES",
#  'ORGANIC EGG YOLKS',
#  'LEAVENING',
#  'SAFFLOWER OIL',
#  'TOFFEE',
#  'HIBISCUS POWDER',
#  'DRY MALT EXTRACT (BARLEY)',
#  'CHOCOLATE CHUNKS WITH VEGETABLE OIL: BELGIAN CHOCOLATE (SUGAR, CHOCOLATE, COCOA BUTTER, SOY LECITHIN, NATURAL FLAVOR)',
#  'NATURAL FLAVOR',
#  'EGG YOLK AND EGG',
#  'CARNAUBA WAX',
#  'SOY LECITHIN',
#  'BLUE 2',
#  'GRAHAM FLOUR',
#  'GROUND VANILLA BEANS',
#  'PROCESSED VANILLA BEANS',
#  'COCOA',
#  'ROASTED PEANUTS',
#  'MONOCALCIUM PHOSPHATE',
#  'MOLASSES',
#  'COCONUT CONCENTRATE',
#  'CORN SYRUP',
#  'INVERT CANE SUGAR',
#  'BELGIAN CHOCOLATE',
#  'EGG AND EGG YOLK',
#  'CARROT POWDER (COLOR)',
#  'ENZYMES',
#  'PISTACHIOS AND SOY INGREDIENTS',
#  'BAKING SODA AND/OR CALCIUM PHOSPHATE',
#  'ARTIFICIAL FLAVORING',
#  'BAKING SODA',
#  'FUDGE SWIRL',
#  'PALM KERNEL',
#  'LACTIC ACID',
#  'AND/OR CALCIUM PHOSPHATE',
#  'CHOCOLATE CHIPS (SUGAR, UNSWEETENED CHOCOLATE, COCOA BUTTER, SOY LECITHIN, NATURAL FLAVOR)',
#  'RASPBERRY PUREE CONCENTRATE',
#  'COFFEE EXTRACT',
#  'CARAMEL (FOR COLOR)',
#  'WAFFLE CONE',
#  'ENRICHED WHEAT FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON,THIAMIN MONONITRATE, RIBOFLAVIN, FOLIC ACID)',
#  'PISTACHIO PASTE',
#  'CHOCOLATE LIQUOR',
#  'ORGANIC GREEN TEA',
#  'NIACIN',
#  'CARAMELIZED SUGAR',
#  'CARROT JUICE CONCENTRATE',
#  'PEPPERMINT CANDY PIECES: (SUGAR, CORN SYRUP, COCONUT OIL, NATURAL FLAVOR, SOY LECITHIN)',
#  'DEXTROSE†',
#  'POWDERED SUGAR (CANE SUGAR, CORNSTARCH)',
#  'SUGAR†',
#  'LECITHIN (SOY)',
#  'YEAST EXTRACT',
#  'MALTITOL',
#  'ORGANIC CAROB BEAN GUM',
#  'CHOCOLATE CHIP COOKIES',
#  'ORGANIC GINGER',
#  'NATURAL FLAVORS',
#  'VANILLIN',
#  'CANOLA OIL',
#  'EGG WHITES',
#  'RICE STARCH',
#  'SODIUM BICARBONATE',
#  'ARTIFICIAL FLAVOR',
#  'PASTEURIZED WHOLE EGGS',
#  'EGGS',
#  'VEGETABLE JUICE (FOR COLOR), PEPPERMINT OIL)',
#  'PEANUT BUTTER FROZEN DESSERT: WATER',
#  'ALMOND MILK',
#  'PASTEURIZED MILK AND CREAM',
#  'PALM KERNEL OIL',
#  'VEGETABLE OIL',
#  'ENRICHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THAIMIN MONONITRATE, RIBOFLAVIN, FOLIC ACID)',
#  'CAROB GUM',
#  'PASTEURIZED MILK',
#  'POTATO',
#  'DARK CHOCOLATE',
#  'GROUND HEATH TOFFEE PIECES',
#  'CHERRIES',
#  'SOYBEAN',
#  'MALTED BARLEY FLOUR',
#  'COCONUT',
#  'HIGH FRUCTOSE CORN SYRUP',
#  'CHERRY CONCENTRATE (FOR COLOR)',
#  'MAPLE SYRUP',
#  'DARK CHOCOLATE AND VEGETABLE OIL COATING: DARK CHOCOLATE (SUGAR, CHOCOLATE, SOY LECITHIN, VANILLA EXTRACT)',
#  'CHEESECAKE PIECES WITH GRAHAM CRUST',
#  'PARTIALLY DEFATTED PEANUT FLOUR']

# %%
dairy
# Out:
#                      0
# 0     Acidophilus Milk
# 1   Ammonium Caseinate
# 2               Butter
# 3        Butter Esters
# 4           Butter Fat
# ..                 ...
# 73     Whipped Topping
# 74          Whole Milk
# 75   Whole Milk Powder
# 76              Yogurt
# 77      Zinc Caseinate
#
# [78 rows x 1 columns]

# %%
##Food order

"""
Q. How are ingredients listed on a product label?
A. Food manufacturers are required to list all ingredients in the food on the label. 
On a product label, the ingredients are listed in order of predominance, 
with the ingredients used in the greatest amount first, followed in descending order by those in smaller amounts. 
The label must list the names of any FDA-certified color additives (e.g., FD&C Blue No. 1 or the abbreviated name, Blue 1). 
But some ingredients can be listed collectively as "flavors," "spices," "artificial flavoring,"
or in the case of color additives exempt from certification, "artificial colors", without naming each one. 
Declaration of an allergenic ingredient in a collective or single color, flavor, or spice 
could be accomplished by simply naming the allergenic ingredient in the ingredient list.

https://www.fda.gov/food/food-ingredients-packaging/overview-food-ingredients-additives-colors


"""

# %%
#Try to separate out sub keywords?

sub_ing_dict = {}
sub_ing_list = []
for i in range(len(ingredients)):
    sub_ing_i = ingredients[i]
    sub_ing_split = sub_ing_i.split(",")
    for ele in sub_ing_split:
        if ele in sub_ing_dict.keys():
            sub_ing_dict[ele] = sub_ing_dict[ele] + 1
        else:
            sub_ing_dict[ele] = 1
    sub_ing_list.append(sub_ing_split)
sub_ing_flat = [ing for sublist in sub_ing_list for ing in sublist]
sub_ingredients = list(set(sub_ing_flat))

# %%
#append ingredients_count column to dataframe

ingCount = []
top20_dict = {}
for i in range(len(df)):
    ing_split = re.split(r'[.,]\s*(?![^()]*\))', df["ingredients"][i])
    ingCount.append(len(ing_split))
    top20_dict[df["key"][i]] = ing_split[0:20]
df["ingredients_count"] = ingCount
df.sort_values(by = "ingredients_count", ascending = False)
# Out:
#        brand         key                                name subhead  \
# 204  breyers  32_breyers             SNICKERS® & M&M'S® 2in1     NaN
# 217  breyers  45_breyers           New York Style Cheesecake     NaN
# 240  breyers  68_breyers  Layered Dessert Brownie Cheesecake     NaN
# 203  breyers  31_breyers                           SNICKERS®     NaN
# 201  breyers  29_breyers       REESE'S & REESE'S PIECES 2in1     NaN
# ..       ...         ...                                 ...     ...
# 66        hd        9_hd                 Chocolate Ice Cream     NaN
# 116       hd       59_hd                   Vanilla Ice Cream     NaN
# 172  breyers   0_breyers                     Natural Vanilla     NaN
# 78        hd       21_hd                    Coffee Ice Cream     NaN
# 112       hd       55_hd                Strawberry Ice Cream     NaN
#
#                                            description  rating  rating_count  \
# 204  SNICKERS® or M&M'S®? When it comes to your fav...     3.9            52
# 217  Can’t get enough of rich, creamy cheesecake? Y...     3.3            36
# 240  Love brownie cheesecake? What about Breyers®? ...     2.8            25
# 203  Breyers® joins forces with America’s favorite ...     4.4           109
# 201  REESE'S PIECES or REESE'S Peanut Butter Cups? ...     3.3            88
# ..                                                 ...     ...           ...
# 66   Rich, creamy, and totally indulgent. Made from...     4.9            90
# 116  Vanilla is the essence of elegance and sophist...     3.0           228
# 172  Our Original Vanilla Ice Cream. The way vanill...     4.1           467
# 78   We roast the finest Brazilian coffee beans and...     4.6           173
# 112  We introduce sweet summer strawberries to pure...     4.8           108
#
#                                            ingredients  ingredients_count
# 204  SKIM MILK, SUGAR, SNICKERS PIECES*, MILK CHOCO...                 77
# 217  NONFAT MILK, STRAWBERRY SWIRL, WATER, SUGAR, C...                 69
# 240  MILK, CORN SYRUP, SUGAR, ENRICHED WHEAT FLOUR,...                 67
# 203  SKIM MILK, SUGAR, CARAMEL SWIRL, CORN SYRUP, W...                 62
# 201  MILK, CORN SYRUP, REESE'S PEANUT BUTTER CUP PI...                 59
# ..                                                 ...                ...
# 66   CREAM, SKIM MILK, CANE SUGAR, COCOA PROCESSED ...                  5
# 116  CREAM, SKIM MILK, CANE SUGAR, EGG YOLKS, VANIL...                  5
# 172  MILK, CREAM, SUGAR, VEGETABLE GUM (TARA), NATU...                  5
# 78     CREAM, SKIM MILK, CANE SUGAR, EGG YOLKS, COFFEE                  5
# 112  CREAM, SKIM MILK, STRAWBERRIES, CANE SUGAR, EG...                  5
#
# [241 rows x 9 columns]

# %%
pd.DataFrame.from_dict(top20_dict, orient = "index")
# Out:
#                0                            1                            2   \
# 0_bj        CREAM                    SKIM MILK  LIQUID SUGAR (SUGAR, WATER)
# 1_bj        CREAM                    SKIM MILK  LIQUID SUGAR (SUGAR, WATER)
# 2_bj        CREAM  LIQUID SUGAR (SUGAR, WATER)                    SKIM MILK
# 3_bj        CREAM                    SKIM MILK  LIQUID SUGAR (SUGAR, WATER)
# 4_bj        CREAM                    SKIM MILK                        WATER
# ...           ...                          ...                          ...
# 64_breyers   MILK                   CORN SYRUP                        SUGAR
# 65_breyers   MILK                        WATER                CARAMEL SWIRL
# 66_breyers   MILK                   CORN SYRUP                        SUGAR
# 67_breyers   MILK                   CORN SYRUP         ENRICHED WHEAT FLOUR
# 68_breyers   MILK                   CORN SYRUP                        SUGAR
#
#                                      3            4   \
# 0_bj                              WATER  BROWN SUGAR
# 1_bj                              WATER        SUGAR
# 2_bj                              WATER        SUGAR
# 3_bj                              WATER   CORN SYRUP
# 4_bj        LIQUID SUGAR (SUGAR, WATER)        SUGAR
# ...                                 ...          ...
# 64_breyers                  BROWN SUGAR  SOYBEAN OIL
# 65_breyers                        SUGAR        WATER
# 66_breyers                  WHEAT FLOUR       BUTTER
# 67_breyers                  WHEAT FLOUR       NIACIN
# 68_breyers         ENRICHED WHEAT FLOUR  WHEAT FLOUR
#
#                                        5                         6   \
# 0_bj                                SUGAR                      MILK
# 1_bj                              PEANUTS               WHEAT FLOUR
# 2_bj        COCOA (PROCESSED WITH ALKALI)                    POTATO
# 3_bj                          COCONUT OIL                     SUGAR
# 4_bj                           CANOLA OIL               SOYBEAN OIL
# ...                                   ...                       ...
# 64_breyers                          WATER                    BUTTER
# 65_breyers                     CORN SYRUP  HIGH FRUCTOSE CORN SYRUP
# 66_breyers                   CREAM (MILK)                      SALT
# 67_breyers                   REDUCED IRON       THIAMIN MONONITRATE
# 68_breyers                         NIACIN              REDUCED IRON
#
#                                            7                        8   \
# 0_bj                              WHEAT FLOUR                EGG YOLKS
# 1_bj                               CANOLA OIL                EGG YOLKS
# 2_bj                              COCONUT OIL        CORN SYRUP SOLIDS
# 3_bj                         DRIED CANE SYRUP                EGG YOLKS
# 4_bj                                EGG YOLKS               CORN SYRUP
# ...                                       ...                      ...
# 64_breyers                              CREAM                     SALT
# 65_breyers                 NONFAT MILK SOLIDS                   BUTTER
# 66_breyers                           PALM OIL               CORN SYRUP
# 67_breyers                         RIBOFLAVIN               FOLIC ACID
# 68_breyers  THIAMINE MONONITRATE (VITAMIN B1)  RIBOFLAVIN (VITAMIN B2)
#
#                      9               10                    11  \
# 0_bj         CORN SYRUP            EGGS  BUTTER (CREAM, SALT)
# 1_bj        CORN STARCH      PEANUT OIL          COCOA POWDER
# 2_bj        SOYBEAN OIL       EGG YOLKS           RICE STARCH
# 3_bj        WHEAT FLOUR            MILK                 COCOA
# 4_bj        WHEAT FLOUR     COCONUT OIL           CORN STARCH
# ...                 ...             ...                   ...
# 64_breyers   CORN SYRUP           SPICE                  SALT
# 65_breyers        CREAM            SALT                  SALT
# 66_breyers  NONFAT MILK           WATER            RICE FLOUR
# 67_breyers        SUGAR          BUTTER                 CREAM
# 68_breyers   FOLIC ACID  POWDERED SUGAR                 SUGAR
#
#                                        12                             13  \
# 0_bj                            BUTTEROIL                         PECTIN
# 1_bj                                 SALT                    SOYBEAN OIL
# 2_bj                        SUNFLOWER OIL                    BARLEY MALT
# 3_bj                       NATURAL FLAVOR                       GUAR GUM
# 4_bj        COCOA (PROCESSED WITH ALKALI)              CORN SYRUP SOLIDS
# ...                                   ...                            ...
# 64_breyers               SOYBEAN LECITHIN                VANILLA EXTRACT
# 65_breyers                       MOLASSES                         PECTIN
# 66_breyers                NATURAL FLAVORS                           SALT
# 67_breyers                           SALT                     CANOLA OIL
# 68_breyers                     CORNSTARCH  COCOA (PROCESSED WITH ALKALI)
#
#                            14                                 15  \
# 0_bj                 SEA SALT                        SOYBEAN OIL
# 1_bj        INVERT CANE SUGAR                           MILK FAT
# 2_bj             COCOA POWDER                        WHEAT FLOUR
# 3_bj             SOY LECITHIN                         BUTTER OIL
# 4_bj                    COCOA                       GRAHAM FLOUR
# ...                       ...                                ...
# 64_breyers   DRIED CANE SYRUP  UNBLEACHED UNENRICHED WHEAT FLOUR
# 65_breyers       SOY LECITHIN                     NATURAL FLAVOR
# 66_breyers        WHEAT FLOUR                              SUGAR
# 67_breyers   SKIM MILK POWDER                               SALT
# 68_breyers              WATER                    PALM KERNEL OIL
#
#                                           16               17  \
# 0_bj                         VANILLA EXTRACT         GUAR GUM
# 1_bj                                    EGGS       EGG WHITES
# 2_bj                                    MILK             SALT
# 3_bj                         NATURAL FLAVORS  LOCUST BEAN GUM
# 4_bj                                    SALT       EGG WHITES
# ...                                      ...              ...
# 64_breyers                       COCONUT OIL            WATER
# 65_breyers  POTASSIUM SORBATE (PRESERVATIVE)   SODIUM CITRATE
# 66_breyers                          PALM OIL         MOLASSES
# 67_breyers                SODIUM BICARBONATE          PEACHES
# 68_breyers                       SOYBEAN OIL  NONFAT DRY MILK
#
#                                    18  \
# 0_bj                     SOY LECITHIN
# 1_bj                         GUAR GUM
# 2_bj                     SOY LECITHIN
# 3_bj                             SALT
# 4_bj                        BUTTEROIL
# ...                               ...
# 64_breyers                     BUTTER
# 65_breyers                LACTIC ACID
# 66_breyers                     SPICES
# 67_breyers                   FRUCTOSE
# 68_breyers  SOY LECITHIN (EMULSIFIER)
#
#                                                            19
# 0_bj        BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODI...
# 1_bj                                             SOY LECITHIN
# 2_bj                                            YEAST EXTRACT
# 3_bj                                              CITRIC ACID
# 4_bj                                           TAPIOCA STARCH
# ...                                                       ...
# 64_breyers                                              CREAM
# 65_breyers                                     MALTITOL SYRUP
# 66_breyers                                               SALT
# 67_breyers                                        COCONUT OIL
# 68_breyers                                    NATURAL FLAVORS
#
# [241 rows x 20 columns]
